# %%
from dotenv import load_dotenv
from anthropic import Anthropic

# Load env Variable
load_dotenv()

# Create an API client
client = Anthropic()
model = "claude-sonnet-4-6"

def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None, temperature=1.0):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature
    }
    
    if system:
        params["system"] = system
    
    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []

# Without system prompt
add_user_message(messages, "Generate a one sentece movie idea")
answer = chat(messages, temperature=0.0)

answer
# Out:
# "Here's a movie idea:\n\n**A retired safecracker with dementia must break into a bank vault before his memory fades completely — because the cure to his disease is locked inside.**"

# %%
messages = []

# Without system prompt
add_user_message(messages, "Generate a one sentece movie idea")
answer = chat(messages, temperature=1.0)

answer
# Out:
# "Here's a movie idea:\n\n**A retired forger is forced out of hiding when she discovers that someone is using her stolen techniques to frame her long-lost daughter for an international art heist.**"
